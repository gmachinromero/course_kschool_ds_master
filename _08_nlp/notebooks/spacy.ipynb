# %%
# install the requirements
# !pip install spacy
# !python -m spacy download es_core_news_md
# !python -m spacy download en_core_web_md

# %% [markdown]
# # `spacy`: el *Ruby on Rails* del PLN
#
# [spacy](http://www.spacy.io/) es una librería de procesamiento del lenguaje natural, robusta, rápida, fácil de instalar y utilizar e integrable con [otras librerías de *NLP* y de *deep learning*](https://spacy.io/usage/facts-figures#section-other-libraries).
#
# Tiene modelos entrenados en varios idiomas y permite realizar las [típicas tareas](https://spacy.io/usage/facts-figures) de segmentación por oraciones, tokenizanción, análisis morfológico, extracción de entidades y análisis de opinión.

# %% [markdown]
# Una vez instalados los modelos, podemos importarlos fácilmente:

# %%
import spacy

# cargamos el modelo entrenado en español
nlp = spacy.load("es_core_news_md")

# %%
texto = """España incumple la regla del déficit del euro y queda como único país bajo el control de Bruselas. 
España no aprobará finalmente la regla europa del déficit y se quedará como único país de la Eurozona que 
suspende y sigue bajo vigilancia. El Gobierno se salta finalmente el requisito de saneamiento presupuestario 
del Tratado de Maastricht y obtiene así más margen de gasto en 2018."""

# y procesamos el texto
doc = nlp(texto)

# %% [markdown]
# ## Procesando oraciones, palabras y entidades
#
# Podemos iterar fácilmente sobre la lista de oraciones y recorrer los tokens para acceder a su información morfo-sintáctica:

# %%
for sentence in doc.sents:
    print("Oración: {}".format(sentence))
    for token in sentence:
        print(
            "{}/{} => etiqueta {}/{} y dependencia {}".format(
                token, token.lemma_, token.pos_, token.tag_, token.dep_
            )
        )
# Out:
# Oración: España incumple la regla del déficit del euro y queda como único país bajo el control de Bruselas.
#
# España/España => etiqueta PROPN/PROPN y dependencia nsubj
# incumple/incumplir => etiqueta VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y dependencia ROOT
# la/lo => etiqueta DET/DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art y dependencia det
# regla/reglar => etiqueta NOUN/NOUN__Gender=Fem|Number=Sing y dependencia obj
# del/del => etiqueta ADP/ADP__AdpType=Preppron y dependencia case
# déficit/déficit => etiqueta NOUN/NOUN__Gender=Masc|Number=Sing y dependencia nmod
# del/del => etiqueta ADP/ADP__AdpType=Preppron y dependencia case
# euro/euro => etiqueta NOUN/NOUN__Gender=Masc|Number=Sing y dependencia nmod
# y/y => etiqueta CCONJ/CCONJ y dependencia cc
# queda/quedo => etiqueta VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y dependencia conj
# como/comer => etiqueta SCONJ/SCONJ y dependencia mark
# único/único => etiqueta ADJ/ADJ__Gender=Masc|Number=Sing y dependencia amod
# país/país => etiqueta NOUN/NOUN__Gender=Masc|Number=Sing y dependencia obj
# bajo/bajar => etiqueta ADP/ADP__AdpType=Prep y dependencia case
# el/el => etiqueta DET/DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art y dependencia det
# control/control => etiqueta NOUN/NOUN__Gender=Masc|Number=Sing y dependencia obl
# de/de => etiqueta ADP/ADP__AdpType=Prep y dependencia case
# Bruselas/Bruselas => etiqueta PROPN/PROPN y dependencia nmod
# ./. => etiqueta PUNCT/PUNCT__PunctType=Peri y dependencia punct
#
# /
#  => etiqueta SPACE/_SP y dependencia
# Oración: España no aprobará finalmente la regla europa del déficit y se quedará como único país de la Eurozona que
# suspende y sigue bajo vigilancia.
# España/España => etiqueta PROPN/PROPN y dependencia nsubj
# no/no => etiqueta ADV/ADV__Polarity=Neg y dependencia advmod
# aprobará/aprobar => etiqueta VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin y dependencia ROOT
# finalmente/finalmente => etiqueta ADV/ADV y dependencia advmod
# la/lo => etiqueta DET/DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art y dependencia det
# regla/reglar => etiqueta NOUN/NOUN__Gender=Fem|Number=Sing y dependencia obj
# europa/europa => etiqueta PROPN/PROPN y dependencia appos
# del/del => etiqueta ADP/ADP__AdpType=Preppron y dependencia case
# déficit/déficit => etiqueta NOUN/NOUN__Gender=Masc|Number=Sing y dependencia nmod
# y/y => etiqueta CCONJ/CCONJ y dependencia cc
# se/se => etiqueta PRON/PRON__Case=Acc,Dat|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes y dependencia obj
# quedará/quedar => etiqueta VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin y dependencia conj
# como/comer => etiqueta SCONJ/SCONJ y dependencia mark
# único/único => etiqueta ADJ/ADJ__Gender=Masc|Number=Sing y dependencia amod
# país/país => etiqueta NOUN/NOUN__Gender=Masc|Number=Sing y dependencia obl
# de/de => etiqueta ADP/ADP__AdpType=Prep y dependencia case
# la/lo => etiqueta DET/DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art y dependencia det
# Eurozona/Eurozona => etiqueta PROPN/PROPN y dependencia nmod
# que/que => etiqueta SCONJ/PRON__PronType=Int,Rel y dependencia obj
#
# /
#  => etiqueta SPACE/_SP y dependencia
# suspende/suspender => etiqueta VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y dependencia advcl
# y/y => etiqueta CCONJ/CCONJ y dependencia cc
# sigue/seguir => etiqueta VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y dependencia conj
# bajo/bajar => etiqueta ADP/ADP__AdpType=Prep y dependencia case
# vigilancia/vigilancia => etiqueta NOUN/NOUN__Gender=Fem|Number=Sing y dependencia obl
# ./. => etiqueta PUNCT/PUNCT__PunctType=Peri y dependencia punct
# Oración: El Gobierno se salta finalmente el requisito de saneamiento presupuestario
# del Tratado de Maastricht y obtiene así más margen de gasto en 2018.
# El/El => etiqueta DET/DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art y dependencia det
# Gobierno/Gobierno => etiqueta PROPN/PROPN y dependencia nsubj
# se/se => etiqueta PRON/PRON__Case=Acc,Dat|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes y dependencia obj
# salta/saltar => etiqueta VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y dependencia ROOT
# finalmente/finalmente => etiqueta ADV/ADV y dependencia advmod
# el/el => etiqueta DET/DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art y dependencia det
# requisito/requerir => etiqueta NOUN/NOUN__Gender=Masc|Number=Sing y dependencia obj
# de/de => etiqueta ADP/ADP__AdpType=Prep y dependencia case
# saneamiento/saneamiento => etiqueta NOUN/NOUN__Gender=Masc|Number=Sing y dependencia nmod
# presupuestario/presupuestario => etiqueta ADJ/ADJ__Gender=Masc|Number=Sing y dependencia amod
#
# /
#  => etiqueta SPACE/_SP y dependencia
# del/del => etiqueta ADP/ADP__AdpType=Preppron y dependencia case
# Tratado/Tratado => etiqueta PROPN/PROPN y dependencia nmod
# de/de => etiqueta ADP/ADP__AdpType=Prep y dependencia case
# Maastricht/Maastricht => etiqueta PROPN/PROPN y dependencia flat
# y/y => etiqueta CCONJ/CCONJ y dependencia cc
# obtiene/obtener => etiqueta VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y dependencia conj
# así/asir => etiqueta ADV/ADV y dependencia advmod
# más/más => etiqueta ADV/ADV__Degree=Cmp y dependencia advmod
# margen/margen => etiqueta NOUN/NOUN__Number=Sing y dependencia obj
# de/de => etiqueta ADP/ADP__AdpType=Prep y dependencia case
# gasto/gastar => etiqueta NOUN/NOUN__Gender=Masc|Number=Sing y dependencia nmod
# en/en => etiqueta ADP/ADP__AdpType=Prep y dependencia case
# 2018/2018 => etiqueta NOUN/NOUN__AdvType=Tim y dependencia obl
# ./. => etiqueta PUNCT/PUNCT__PunctType=Peri y dependencia punct

# %% [markdown]
# El elemeno `doc` tiene una propiedad `.ents` que permite acceder a las entidades nombradas que hayan sido localizadas:

# %%
print(doc.ents)

for entity in doc.ents:
    print("{} es de tipo {}".format(entity, entity.label_))
# Out:
# (España, Bruselas, España, Eurozona, El Gobierno, Tratado de Maastricht)
# España es de tipo LOC
# Bruselas es de tipo LOC
# España es de tipo LOC
# Eurozona es de tipo ORG
# El Gobierno es de tipo LOC
# Tratado de Maastricht es de tipo MISC

# %% [markdown]
# ## Visualizando árboles de dependencias y entidades
#
# Podemos acceder al árbol completo a través del método `.print_tree()`:

# %%
doc.to_json()
# Out:
# {'text': 'España incumple la regla del déficit del euro y queda como único país bajo el control de Bruselas. \nEspaña no aprobará finalmente la regla europa del déficit y se quedará como único país de la Eurozona que \nsuspende y sigue bajo vigilancia. El Gobierno se salta finalmente el requisito de saneamiento presupuestario \ndel Tratado de Maastricht y obtiene así más margen de gasto en 2018.',
#  'ents': [{'start': 0, 'end': 6, 'label': 'LOC'},
#   {'start': 89, 'end': 97, 'label': 'LOC'},
#   {'start': 100, 'end': 106, 'label': 'LOC'},
#   {'start': 193, 'end': 201, 'label': 'ORG'},
#   {'start': 241, 'end': 252, 'label': 'LOC'},
#   {'start': 321, 'end': 342, 'label': 'MISC'}],
#  'sents': [{'start': 0, 'end': 100},
#   {'start': 100, 'end': 240},
#   {'start': 241, 'end': 385}],
#  'tokens': [{'id': 0,
#    'start': 0,
#    'end': 6,
#    'pos': 'PROPN',
#    'tag': 'PROPN',
#    'dep': 'nsubj',
#    'head': 1},
#   {'id': 1,
#    'start': 7,
#    'end': 15,
#    'pos': 'VERB',
#    'tag': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'dep': 'ROOT',
#    'head': 1},
#   {'id': 2,
#    'start': 16,
#    'end': 18,
#    'pos': 'DET',
#    'tag': 'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#    'dep': 'det',
#    'head': 3},
#   {'id': 3,
#    'start': 19,
#    'end': 24,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Fem|Number=Sing',
#    'dep': 'obj',
#    'head': 1},
#   {'id': 4,
#    'start': 25,
#    'end': 28,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Preppron',
#    'dep': 'case',
#    'head': 5},
#   {'id': 5,
#    'start': 29,
#    'end': 36,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Masc|Number=Sing',
#    'dep': 'nmod',
#    'head': 3},
#   {'id': 6,
#    'start': 37,
#    'end': 40,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Preppron',
#    'dep': 'case',
#    'head': 7},
#   {'id': 7,
#    'start': 41,
#    'end': 45,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Masc|Number=Sing',
#    'dep': 'nmod',
#    'head': 5},
#   {'id': 8,
#    'start': 46,
#    'end': 47,
#    'pos': 'CCONJ',
#    'tag': 'CCONJ',
#    'dep': 'cc',
#    'head': 9},
#   {'id': 9,
#    'start': 48,
#    'end': 53,
#    'pos': 'VERB',
#    'tag': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'dep': 'conj',
#    'head': 1},
#   {'id': 10,
#    'start': 54,
#    'end': 58,
#    'pos': 'SCONJ',
#    'tag': 'SCONJ',
#    'dep': 'mark',
#    'head': 12},
#   {'id': 11,
#    'start': 59,
#    'end': 64,
#    'pos': 'ADJ',
#    'tag': 'ADJ__Gender=Masc|Number=Sing',
#    'dep': 'amod',
#    'head': 12},
#   {'id': 12,
#    'start': 65,
#    'end': 69,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Masc|Number=Sing',
#    'dep': 'obj',
#    'head': 9},
#   {'id': 13,
#    'start': 70,
#    'end': 74,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Prep',
#    'dep': 'case',
#    'head': 15},
#   {'id': 14,
#    'start': 75,
#    'end': 77,
#    'pos': 'DET',
#    'tag': 'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#    'dep': 'det',
#    'head': 15},
#   {'id': 15,
#    'start': 78,
#    'end': 85,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Masc|Number=Sing',
#    'dep': 'obl',
#    'head': 9},
#   {'id': 16,
#    'start': 86,
#    'end': 88,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Prep',
#    'dep': 'case',
#    'head': 17},
#   {'id': 17,
#    'start': 89,
#    'end': 97,
#    'pos': 'PROPN',
#    'tag': 'PROPN',
#    'dep': 'nmod',
#    'head': 15},
#   {'id': 18,
#    'start': 97,
#    'end': 98,
#    'pos': 'PUNCT',
#    'tag': 'PUNCT__PunctType=Peri',
#    'dep': 'punct',
#    'head': 1},
#   {'id': 19,
#    'start': 99,
#    'end': 100,
#    'pos': 'SPACE',
#    'tag': '_SP',
#    'dep': '',
#    'head': 18},
#   {'id': 20,
#    'start': 100,
#    'end': 106,
#    'pos': 'PROPN',
#    'tag': 'PROPN',
#    'dep': 'nsubj',
#    'head': 22},
#   {'id': 21,
#    'start': 107,
#    'end': 109,
#    'pos': 'ADV',
#    'tag': 'ADV__Polarity=Neg',
#    'dep': 'advmod',
#    'head': 22},
#   {'id': 22,
#    'start': 110,
#    'end': 118,
#    'pos': 'VERB',
#    'tag': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin',
#    'dep': 'ROOT',
#    'head': 22},
#   {'id': 23,
#    'start': 119,
#    'end': 129,
#    'pos': 'ADV',
#    'tag': 'ADV',
#    'dep': 'advmod',
#    'head': 22},
#   {'id': 24,
#    'start': 130,
#    'end': 132,
#    'pos': 'DET',
#    'tag': 'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#    'dep': 'det',
#    'head': 25},
#   {'id': 25,
#    'start': 133,
#    'end': 138,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Fem|Number=Sing',
#    'dep': 'obj',
#    'head': 22},
#   {'id': 26,
#    'start': 139,
#    'end': 145,
#    'pos': 'PROPN',
#    'tag': 'PROPN',
#    'dep': 'appos',
#    'head': 25},
#   {'id': 27,
#    'start': 146,
#    'end': 149,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Preppron',
#    'dep': 'case',
#    'head': 28},
#   {'id': 28,
#    'start': 150,
#    'end': 157,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Masc|Number=Sing',
#    'dep': 'nmod',
#    'head': 25},
#   {'id': 29,
#    'start': 158,
#    'end': 159,
#    'pos': 'CCONJ',
#    'tag': 'CCONJ',
#    'dep': 'cc',
#    'head': 31},
#   {'id': 30,
#    'start': 160,
#    'end': 162,
#    'pos': 'PRON',
#    'tag': 'PRON__Case=Acc,Dat|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes',
#    'dep': 'obj',
#    'head': 31},
#   {'id': 31,
#    'start': 163,
#    'end': 170,
#    'pos': 'VERB',
#    'tag': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin',
#    'dep': 'conj',
#    'head': 22},
#   {'id': 32,
#    'start': 171,
#    'end': 175,
#    'pos': 'SCONJ',
#    'tag': 'SCONJ',
#    'dep': 'mark',
#    'head': 34},
#   {'id': 33,
#    'start': 176,
#    'end': 181,
#    'pos': 'ADJ',
#    'tag': 'ADJ__Gender=Masc|Number=Sing',
#    'dep': 'amod',
#    'head': 34},
#   {'id': 34,
#    'start': 182,
#    'end': 186,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Masc|Number=Sing',
#    'dep': 'obl',
#    'head': 31},
#   {'id': 35,
#    'start': 187,
#    'end': 189,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Prep',
#    'dep': 'case',
#    'head': 37},
#   {'id': 36,
#    'start': 190,
#    'end': 192,
#    'pos': 'DET',
#    'tag': 'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#    'dep': 'det',
#    'head': 37},
#   {'id': 37,
#    'start': 193,
#    'end': 201,
#    'pos': 'PROPN',
#    'tag': 'PROPN',
#    'dep': 'nmod',
#    'head': 34},
#   {'id': 38,
#    'start': 202,
#    'end': 205,
#    'pos': 'SCONJ',
#    'tag': 'PRON__PronType=Int,Rel',
#    'dep': 'obj',
#    'head': 40},
#   {'id': 39,
#    'start': 206,
#    'end': 207,
#    'pos': 'SPACE',
#    'tag': '_SP',
#    'dep': '',
#    'head': 38},
#   {'id': 40,
#    'start': 207,
#    'end': 215,
#    'pos': 'VERB',
#    'tag': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'dep': 'advcl',
#    'head': 31},
#   {'id': 41,
#    'start': 216,
#    'end': 217,
#    'pos': 'CCONJ',
#    'tag': 'CCONJ',
#    'dep': 'cc',
#    'head': 42},
#   {'id': 42,
#    'start': 218,
#    'end': 223,
#    'pos': 'VERB',
#    'tag': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'dep': 'conj',
#    'head': 40},
#   {'id': 43,
#    'start': 224,
#    'end': 228,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Prep',
#    'dep': 'case',
#    'head': 44},
#   {'id': 44,
#    'start': 229,
#    'end': 239,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Fem|Number=Sing',
#    'dep': 'obl',
#    'head': 42},
#   {'id': 45,
#    'start': 239,
#    'end': 240,
#    'pos': 'PUNCT',
#    'tag': 'PUNCT__PunctType=Peri',
#    'dep': 'punct',
#    'head': 22},
#   {'id': 46,
#    'start': 241,
#    'end': 243,
#    'pos': 'DET',
#    'tag': 'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#    'dep': 'det',
#    'head': 47},
#   {'id': 47,
#    'start': 244,
#    'end': 252,
#    'pos': 'PROPN',
#    'tag': 'PROPN',
#    'dep': 'nsubj',
#    'head': 49},
#   {'id': 48,
#    'start': 253,
#    'end': 255,
#    'pos': 'PRON',
#    'tag': 'PRON__Case=Acc,Dat|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes',
#    'dep': 'obj',
#    'head': 49},
#   {'id': 49,
#    'start': 256,
#    'end': 261,
#    'pos': 'VERB',
#    'tag': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'dep': 'ROOT',
#    'head': 49},
#   {'id': 50,
#    'start': 262,
#    'end': 272,
#    'pos': 'ADV',
#    'tag': 'ADV',
#    'dep': 'advmod',
#    'head': 49},
#   {'id': 51,
#    'start': 273,
#    'end': 275,
#    'pos': 'DET',
#    'tag': 'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#    'dep': 'det',
#    'head': 52},
#   {'id': 52,
#    'start': 276,
#    'end': 285,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Masc|Number=Sing',
#    'dep': 'obj',
#    'head': 49},
#   {'id': 53,
#    'start': 286,
#    'end': 288,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Prep',
#    'dep': 'case',
#    'head': 54},
#   {'id': 54,
#    'start': 289,
#    'end': 300,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Masc|Number=Sing',
#    'dep': 'nmod',
#    'head': 52},
#   {'id': 55,
#    'start': 301,
#    'end': 315,
#    'pos': 'ADJ',
#    'tag': 'ADJ__Gender=Masc|Number=Sing',
#    'dep': 'amod',
#    'head': 54},
#   {'id': 56,
#    'start': 316,
#    'end': 317,
#    'pos': 'SPACE',
#    'tag': '_SP',
#    'dep': '',
#    'head': 55},
#   {'id': 57,
#    'start': 317,
#    'end': 320,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Preppron',
#    'dep': 'case',
#    'head': 58},
#   {'id': 58,
#    'start': 321,
#    'end': 328,
#    'pos': 'PROPN',
#    'tag': 'PROPN',
#    'dep': 'nmod',
#    'head': 52},
#   {'id': 59,
#    'start': 329,
#    'end': 331,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Prep',
#    'dep': 'case',
#    'head': 60},
#   {'id': 60,
#    'start': 332,
#    'end': 342,
#    'pos': 'PROPN',
#    'tag': 'PROPN',
#    'dep': 'flat',
#    'head': 58},
#   {'id': 61,
#    'start': 343,
#    'end': 344,
#    'pos': 'CCONJ',
#    'tag': 'CCONJ',
#    'dep': 'cc',
#    'head': 62},
#   {'id': 62,
#    'start': 345,
#    'end': 352,
#    'pos': 'VERB',
#    'tag': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'dep': 'conj',
#    'head': 49},
#   {'id': 63,
#    'start': 353,
#    'end': 356,
#    'pos': 'ADV',
#    'tag': 'ADV',
#    'dep': 'advmod',
#    'head': 62},
#   {'id': 64,
#    'start': 357,
#    'end': 360,
#    'pos': 'ADV',
#    'tag': 'ADV__Degree=Cmp',
#    'dep': 'advmod',
#    'head': 65},
#   {'id': 65,
#    'start': 361,
#    'end': 367,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Number=Sing',
#    'dep': 'obj',
#    'head': 62},
#   {'id': 66,
#    'start': 368,
#    'end': 370,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Prep',
#    'dep': 'case',
#    'head': 67},
#   {'id': 67,
#    'start': 371,
#    'end': 376,
#    'pos': 'NOUN',
#    'tag': 'NOUN__Gender=Masc|Number=Sing',
#    'dep': 'nmod',
#    'head': 65},
#   {'id': 68,
#    'start': 377,
#    'end': 379,
#    'pos': 'ADP',
#    'tag': 'ADP__AdpType=Prep',
#    'dep': 'case',
#    'head': 69},
#   {'id': 69,
#    'start': 380,
#    'end': 384,
#    'pos': 'NOUN',
#    'tag': 'NOUN__AdvType=Tim',
#    'dep': 'obl',
#    'head': 62},
#   {'id': 70,
#    'start': 384,
#    'end': 385,
#    'pos': 'PUNCT',
#    'tag': 'PUNCT__PunctType=Peri',
#    'dep': 'punct',
#    'head': 49}]}

# %% [markdown]
# Pero también se puede dibujar el grafo con las dependencias:

# %%
from spacy import displacy

displacy.serve(doc, style="dep")
# Out:
# /home/victor/miniconda3/envs/nlp/lib/python3.7/site-packages/spacy/displacy/__init__.py:94: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="es">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="4db472d042294c7c82117ad0a53ca6bf-0" class="displacy" width="11950" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">España</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">incumple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">regla</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">del</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">déficit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">del</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">euro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">queda</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">como</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">único</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">país</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">bajo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">el</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">control</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Bruselas.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">España</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">aprobará</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">finalmente</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">regla</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">europa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">del</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">déficit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="c
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# O el de las entidades:

# %%
from spacy import displacy

displacy.serve(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="es">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     España
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  incumple la regla del déficit del euro y queda como único país bajo el control de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bruselas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . </br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     España
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  no aprobará finalmente la regla europa del déficit y se quedará como único país de la
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eurozona
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  que </br>suspende y sigue bajo vigilancia.
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Gobierno
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  se salta finalmente el requisito de saneamiento presupuestario </br>del
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tratado de Maastricht
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  y obtiene así más margen de gasto en 2018.</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
texto = """Los ciudadanos españoles son conscientes de que esa salida de Reino Unido no será gratuita. Literalmente. Uno de cada tres teme que el Brexit le cueste caro a la economía española: el 36,9% prevé consecuencias «muy negativas» para sus bolsillos."""
doc = nlp(texto)
displacy.serve(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="es">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">Los ciudadanos españoles son conscientes de que esa salida de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reino Unido
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  no será gratuita.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Literalmente.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Uno de cada tres teme
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  que el
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brexit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  le cueste caro a la economía española: el 36,9% prevé consecuencias «muy negativas» para sus bolsillos.</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
nlp_en = spacy.load("en_core_web_md")

# %%
text = """A trade war between the world’s two largest economies officially began on Friday morning as the Trump 
administration followed through with its threat to impose tariffs on $34 billion worth of Chinese products, a 
significant escalation of a fight that could hurt companies and consumers in both the United States and China."""
doc = nlp_en(text)
displacy.serve(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">A trade war between the world’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  largest economies officially began on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  as the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </br>administration followed through with its threat to impose tariffs on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $34 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  products, a </br>significant escalation of a fight that could hurt companies and consumers in both
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# ## Similitud semántica entre palabras, frases y documentos
#
# spaCy permite [calcular la similitud semántica](https://spacy.io/usage/vectors-similarity) entre cualquier par de objetos de tipo `Doc`, `Span` o `Token`.
#
# Ojo, La similitud semántica es un concepto algo subjetivo, pero en este caso se puede entender como la probabilidad de que dos palabras aparezcan en los mismos contextos.

# %%
# analizamos algunas colocaciones en inglés
token1, _, token2 = nlp_en("cats and dogs")
token3, _, token4 = nlp_en("research and development")

# medimos la similitud semántica entre algunos pares
print(token1, "vs", token2, token1.similarity(token2))
print(token3, "vs", token4, token3.similarity(token4))
print(token1, "vs", token4, token1.similarity(token4))
# Out:
# cats vs dogs 0.83117634
# research vs development 0.5828718
# cats vs development 0.104666404

# %%
# ¿qué tal funciona en español?
token1, _, token2 = nlp("perros y gatos")
token3, _, token4 = nlp("investigación y desarrollo")

# medimos la similitud semántica entre algunos pares
print(token1, "vs", token2, token1.similarity(token2))
print(token3, "vs", token4, token3.similarity(token4))
print(token1, "vs", token4, token1.similarity(token4))
# Out:
# perros vs gatos 0.87088835
# investigación vs desarrollo 0.69238174
# perros vs desarrollo 0.016273146

# %%
token1.vector.shape
# Out:
# (300,)

# %%
print(token1.vector)
# Out:
# [ 4.1870e+00  2.9879e+00 -4.7788e-01  7.1432e-03  1.4423e+00 -6.2299e-01
#  -3.7585e+00 -4.1798e-01  1.9699e+00  3.7113e+00 -1.0867e+00  3.4953e-01
#   2.3197e+00  1.4713e+00 -1.8833e+00  8.7245e-02 -2.0503e+00 -2.3009e+00
#   2.4353e-01 -3.9290e+00  1.6590e-01 -2.4178e-01  6.5346e-01  2.4065e+00
#  -1.3074e+00 -2.6448e+00  8.2543e-01 -3.2517e-01  2.1029e-01  2.9923e+00
#  -2.2777e+00  3.9615e+00  1.0714e+00  4.9930e-02 -6.9514e-01 -6.6236e-01
#  -8.9033e-01 -6.8197e-01  1.3586e+00  1.3103e-04 -1.1174e+00  2.2623e+00
#  -4.9142e+00  5.3017e-01 -2.1343e+00 -1.6264e+00 -2.5723e-01  1.1757e+00
#   1.3982e+00  1.3306e+00  2.1556e+00  9.7813e-01  4.0708e-02 -2.2519e-01
#  -1.9099e+00 -3.1959e-01  1.3120e+00  1.0037e+00 -1.3192e+00  1.3133e+00
#   2.1475e-02  1.3223e+00  1.2912e+00 -2.2622e+00  2.1667e-01  7.8707e-01
#   2.0105e+00 -3.1540e+00 -2.3959e+00 -1.3868e+00  1.9939e+00  2.0524e+00
#  -1.5997e+00 -1.3165e+00 -1.3275e+00 -9.5451e-01  1.2380e+00  1.1141e+00
#  -3.1573e+00 -3.8136e+00 -1.6776e-01  3.4885e-01  1.1793e+00 -8.0497e-01
#  -2.1403e+00  2.5826e+00  2.4417e-01 -5.2336e-01 -1.6067e+00  2.5381e-01
#   1.6750e+00  1.2464e+00  2.2635e-01 -1.1194e+00  7.5922e-02 -8.0847e-01
#  -2.4323e-01 -5.5243e-01  5.8090e-01  1.5008e+00 -9.6945e-01  9.0188e-01
#  -8.3858e-01  9.9861e-01  4.2640e-01  1.5424e+00 -3.7809e+00  8.0740e-01
#  -1.4292e+00  1.7325e-01 -1.4536e+00  1.4022e+00 -1.7334e+00  7.5239e-01
#   2.8940e+00  7.6846e-01 -3.9244e+00  1.9927e+00 -3.1001e+00 -1.1998e+00
#  -6.0544e-01 -2.4791e+00  9.6846e-02 -4.1992e-01 -1.9951e+00 -6.2477e-01
#  -5.3311e-01  9.4677e-01  5.2586e-01  1.0429e+00 -1.5587e-01  1.6212e+00
#   9.0078e-01  1.3241e+00  1.7167e+00  5.9660e-01  1.0919e-01  5.7239e+00
#  -2.0288e+00 -8.3535e-01  1.1382e-01  4.7189e-01  5.6154e-01  1.3513e+00
#   6.7937e-02  1.8476e+00 -1.7959e+00 -1.3658e+00  2.1921e-01  3.5519e+00
#  -5.8726e-01 -1.1337e+00 -2.3835e+00  1.2441e+00 -1.7037e+00  1.5429e-01
#  -1.4079e+00  5.9405e-01  3.5173e+00 -4.9972e+00 -4.9684e-01 -2.9381e-01
#   4.8109e-01  8.5680e-01 -1.1086e+00  3.2435e+00 -2.3043e+00 -1.0760e+00
#   1.0229e+00  2.7825e+00 -4.9621e-01  2.1868e+00 -2.6190e-01  9.7963e-01
#  -3.1519e-01 -1.8862e-01  1.3866e+00  4.0507e+00 -2.2858e-02  2.7815e+00
#  -3.5830e-01  5.6846e-01 -1.0838e-01  2.2763e+00  7.5925e-01  7.3281e-01
#  -1.4077e+00  2.4812e+00  2.3551e+00 -4.0798e-01  2.2845e+00  1.5986e+00
#   9.3490e-01  1.3901e+00  2.7409e-01 -1.3816e+00  1.0832e-01  1.9505e-01
#   3.4612e-01  2.1050e-02 -2.2547e+00 -1.8166e-01 -3.9068e-01 -1.9475e+00
#  -2.9193e+00 -2.9109e+00 -1.8112e+00 -2.7742e+00  4.9774e-01 -1.1633e+00
#  -3.5047e+00  1.8748e-01 -3.1447e-01  1.0435e+00  2.2448e+00  1.7487e+00
#   1.9172e+00  1.2697e+00  1.0176e+00  9.5475e-02 -3.5833e+00 -2.6338e+00
#  -7.5590e-01  2.3704e+00  2.3935e+00  2.7985e+00 -2.8616e-01  2.7953e-01
#   2.0096e-01 -1.0299e-01 -2.0493e+00  3.1625e-01  8.1103e-02  1.0586e+00
#  -1.4619e+00  6.2331e-02  2.0979e-01 -3.5744e-01  2.4471e-01 -9.4306e-01
#   8.8474e-02  8.0937e-01 -4.1138e-01  2.4793e+00  1.0686e+00  3.3599e-01
#  -1.1395e+00  2.2308e+00  1.1828e+00  1.7980e+00 -2.5981e-01  2.5787e+00
#   9.1647e-01  4.6616e-01  1.0781e+00 -2.8698e+00 -1.1343e+00  3.2077e-01
#  -3.0550e-01 -2.4872e+00 -3.1121e+00 -3.3859e-01  2.7052e+00 -1.8841e+00
#  -3.1637e+00  2.4377e+00 -2.0104e+00  2.8854e+00 -1.0398e-01  7.0973e-01
#   1.2407e+00 -1.0718e+00 -3.7989e+00 -7.4717e-01  1.9978e-01  4.3217e-01
#  -1.3098e-01  1.5254e+00  1.3688e+00 -2.8226e+00 -1.5562e+00  1.2494e+00
#  -4.6370e-01 -1.6439e-01 -2.6029e+00  4.2625e-01  2.5033e-01  1.7883e+00
#  -2.0511e-01  3.4332e+00 -1.6186e-01  4.1729e-01  1.0800e-01  1.4299e-01
#   4.8458e-01 -3.1477e+00  2.0588e+00 -2.0710e+00  7.4902e-01  2.0105e+00]
